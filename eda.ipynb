# %% [markdown]
# # Basic Dataset Info
#
# ### Key Findings:
#
# * Rows where 'fipscode' is null will be dropped
# * 9020 county rows for 'Uninsured' and 'Children in poverty' measures are missing FIPS codes due to a data sourcing issue. Dropped from dataset, measure still partially represented by rows with valid FIPS codes
# * 561 state/national aggregate rows will be dropped as out of scope.
# * Data quality issue with Kalawao County, HI. 10 unemployment rows with '.' as year span. Dropped as analytically unusable
# * Some measures don't have numerator/denominator
# * Duplicate fipscodes from Alaska's borough reorganization. Resolved by keeping first occurrence per fipscode"
# * Data Release Year dropped as 50% was null
#
# ***Scale:*** Dataset contains 293,714 observations across 12 health measures and ~3,000 counties after cleaning.

# %%
import pandas as pd

df = pd.read_csv('./data/County_Health_Rankings.csv')

# Display basic information
print(f"Dataset Shape: {df.shape}")
df.head(10)
# Out:
# Dataset Shape: (303864, 14)
#   State         County  State code  County code  Year span  \
# 0    US  United States         0.0          0.0  2003-2005
# 1    US  United States         0.0          0.0  2004-2006
# 2    US  United States         0.0          0.0  2005-2007
# 3    US  United States         0.0          0.0  2006-2008
# 4    US  United States         0.0          0.0  2007-2009
# 5    US  United States         0.0          0.0  2008-2010
# 6    US  United States         0.0          0.0  2009-2011
# 7    AL        Alabama         1.0          0.0  2003-2005
# 8    AL        Alabama         1.0          0.0  2004-2006
# 9    AL        Alabama         1.0          0.0  2005-2007
#
#          Measure name  Measure id     Numerator   Denominator   Raw value  \
# 0  Violent crime rate        43.0  1.328751e+06  2.748771e+08  483.398066
# 1  Violent crime rate        43.0  1.340929e+06  2.776128e+08  483.021233
# ...

# %%
print("Dataset Overview:")
print("=" * 50)
print(f"Total samples: {len(df)}\n")
print(df.info())
# Out:
# Dataset Overview:
# ...
# Total samples: 303864
#
# <class 'pandas.DataFrame'>
# RangeIndex: 303864 entries, 0 to 303863
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   State                            303858 non-null  str
#  1   County                           303858 non-null  str
#  2   State code                       303860 non-null  float64
#  3   County code                      303860 non-null  float64
#  4   Year span                        303390 non-null  str
#  5   Measure name                     303390 non-null  str
#  6   Measure id                       303390 non-null  float64
#  7   Numerator                        214076 non-null  float64
#  8   Denominator                      184779 non-null  float64
#  9   Raw value                        289956 non-null  float64
#  10  Confidence Interval Lower Bound  189412 non-null  float64
# ...

# %%
measure_names_df = pd.DataFrame({'Measure Names': df['Measure name'].unique()})
print("Unique Measure Names:")
display(measure_names_df)
# Out:
# Unique Measure Names:
#                       Measure Names
# 0                Violent crime rate
# 1                      Unemployment
# 2               Children in poverty
# 3                               NaN
# 4                Diabetic screening
# 5             Mammography screening
# 6        Preventable hospital stays
# 7                         Uninsured
# 8   Sexually transmitted infections
# 9               Physical inactivity
# 10                    Adult obesity
# 11                  Premature Death
# 12    Daily fine particulate matter

# %%
year_span_df = pd.DataFrame({'Year spans': df['Year span'].unique()})
print("Unique Year Spans:")
display(year_span_df)
# Out:
# Unique Year Spans:
#    Year spans
# 0   2003-2005
# 1   2004-2006
# 2   2005-2007
# 3   2006-2008
# 4   2007-2009
# 5   2008-2010
# 6   2009-2011
# 7        2002
# 8        2003
# 9        2004
# 10       2005
# 11       2006
# 12       2007
# 13       2008
# 14       2009
# 15       2010
# 16       2011
# 17       2012
# 18          .
# 19        NaN
# 20  2006-2007
# 21  1997-1999
# 22  1998-2000
# 23  1999-2001
# 24  2000-2002
# 25  2001-2003
# 26  2002-2004

# %% [markdown]
# ## Handling Missing Values

# %%
# Checking for missing values
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100
missing_df = pd.DataFrame({'Missing Values': missing_values, 
                           'Percentage (%)': missing_percentage})
missing_df = missing_df[missing_df['Missing Values'] > 0].sort_values('Percentage (%)', ascending=False)

print("Missing Values Analysis:")
display(missing_df)
# Out:
# Missing Values Analysis:
#                                  Missing Values  Percentage (%)
# Data Release Year                        153735       50.593358
# Denominator                              119085       39.190230
# Confidence Interval Upper Bound          114452       37.665535
# Confidence Interval Lower Bound          114452       37.665535
# Numerator                                 89788       29.548745
# Raw value                                 13908        4.577048
# fipscode                                   9581        3.153055
# Year span                                   474        0.155991
# Measure name                                474        0.155991
# Measure id                                  474        0.155991
# State                                         6        0.001975
# County                                        6        0.001975
# State code                                    4        0.001316
# ...

# %% [markdown]
# ## Further Analysis on 'fipscode' Missing Values

# %%
df[df['fipscode'].isnull()]['State'].unique()
df[df['fipscode'].isnull()]['County'].unique()
# Out:
# <StringArray>
# [     'United States',            'Alabama',     'Autauga County',
#      'Baldwin County',     'Barbour County',        'Bibb County',
#       'Blount County',     'Bullock County',      'Butler County',
#      'Calhoun County',
#  ...
#       'Goshen County', 'Hot Springs County',     'Laramie County',
#      'Natrona County',    'Niobrara County',    'Sublette County',
#   'Sweetwater County',       'Uinta County',    'Washakie County',
#       'Weston County']
# Length: 1927, dtype: str

# %%
df[df['fipscode'].isnull()][['State', 'County', 'Measure name', 'Raw value']].head(20)
# Out:
#       State           County         Measure name  Raw value
# 57565    US    United States  Children in poverty      0.226
# 57578    AL          Alabama  Children in poverty      0.276
# 57591    AL   Autauga County  Children in poverty      0.185
# 57604    AL   Baldwin County  Children in poverty      0.205
# 57617    AL   Barbour County  Children in poverty      0.470
# 57630    AL      Bibb County  Children in poverty      0.272
# 57643    AL    Blount County  Children in poverty      0.231
# 57656    AL   Bullock County  Children in poverty      0.432
# 57669    AL    Butler County  Children in poverty      0.421
# 57682    AL   Calhoun County  Children in poverty      0.314
# 57695    AL  Chambers County  Children in poverty      0.347
# 57708    AL  Cherokee County  Children in poverty      0.299
# 57721    AL   Chilton County  Children in poverty      0.302
# 57734    AL   Choctaw County  Children in poverty      0.301
# ...

# %%
df[df['fipscode'].isnull()]['County'].str.contains('County').value_counts()
# Out:
# County
# True     9020
# False     561
# Name: count, dtype: int64

# %%
df[(df['fipscode'].isnull()) & (df['County'].str.contains('County'))][['State', 'County', 'Measure name']].head(20)
# Out:
#       State            County         Measure name
# 57591    AL    Autauga County  Children in poverty
# 57604    AL    Baldwin County  Children in poverty
# 57617    AL    Barbour County  Children in poverty
# 57630    AL       Bibb County  Children in poverty
# 57643    AL     Blount County  Children in poverty
# 57656    AL    Bullock County  Children in poverty
# 57669    AL     Butler County  Children in poverty
# 57682    AL    Calhoun County  Children in poverty
# 57695    AL   Chambers County  Children in poverty
# 57708    AL   Cherokee County  Children in poverty
# 57721    AL    Chilton County  Children in poverty
# 57734    AL    Choctaw County  Children in poverty
# 57747    AL     Clarke County  Children in poverty
# 57760    AL       Clay County  Children in poverty
# 57773    AL   Cleburne County  Children in poverty
# 57786    AL     Coffee County  Children in poverty
# 57799    AL    Colbert County  Children in poverty
# ...

# %%
df[(df['fipscode'].isnull()) & (df['County'].str.contains('County'))]['Measure name'].value_counts()
# Out:
# Measure name
# Uninsured              6013
# Children in poverty    3007
# Name: count, dtype: int64

# %% [markdown]
# ### Summary:
#
# Rows where 'fipscode' is null will be dropped
# 9020 county rows for 'Uninsured' and 'Children in poverty'
# measures are missing FIPS codes due to a data sourcing issue.
# 561 state/national aggregate rows will be dropped as out of scope.

# %%
df[df['State'].isnull()]
# Out:
#        State County  State code  County code  Year span     Measure name  \
# 157161   NaN    NaN         2.0        105.0       2008        Uninsured
# 157228   NaN    NaN         2.0        230.0       2008        Uninsured
# 272420   NaN    NaN         NaN          NaN  1997-1999  Premature Death
# 272421   NaN    NaN         NaN          NaN  1998-2000  Premature Death
# 272422   NaN    NaN         NaN          NaN  1999-2001  Premature Death
# 272423   NaN    NaN         NaN          NaN  2000-2002  Premature Death
#
#         Measure id  Numerator  Denominator  Raw value  \
# 157161        85.0      600.0       1980.0      0.303
# 157228        85.0      153.0        792.0      0.193
# 272420         1.0       97.0          NaN   9197.000
# 272421         1.0       88.0          NaN   8781.000
# 272422         1.0       52.0          NaN        NaN
# 272423         1.0       23.0          NaN        NaN
#
# ...

# %%
# Check for duplicates
print("-" * 50)
print(f"Duplicate entries: {df.duplicated().sum()}")
# Out:
# --------------------------------------------------
# Duplicate entries: 6793

# %% [markdown]
# ## Generate Cleaned Dataset
#
# \* According to steps in load_data.py

# %%
 # ----Cleaning---- #

# Drop rows with missing values in 'Measure name', 'fipscode', and 'County' columns
df = df[df['Measure name'].notna()]
df = df[df['fipscode'].notna()]
df = df[df['County'].notna()]

# Formating 'fipscode'
df['fipscode'] = df['fipscode'].astype(int).astype(str).str.zfill(5)
df = df[df['fipscode'] != '00000']

# Split 'Year span' into 'year_start' and 'year_end'
split = df['Year span'].str.split('-', expand=True)
df['year_start'] = split[0].replace('.', None)
df['year_end'] = split[1].fillna(split[0]).replace('.', None)

# Convert to integer (nullable)
df['year_start'] = pd.to_numeric(df['year_start'], errors='coerce')
df['year_end'] = pd.to_numeric(df['year_end'], errors='coerce')

# Boolean flag for null raw_value
df['raw_value_missing'] = df['Raw value'].isna()

# Drop unnecessary columns
df = df.drop(columns=['Data Release Year', 'State code', 'County code', 'Year span'])

# Rename columns to match database schema
df = df.rename(columns={
    'Measure name': 'measure_name',
    'Measure id': 'measure_id',
    'Denominator': 'denominator',
    'Numerator': 'numerator',
    'Raw value': 'raw_value',
    'Confidence Interval Upper Bound': 'ci_upper',
    'Confidence Interval Lower Bound': 'ci_lower',
    'State': 'state_name',
    'County': 'county_name'})

# Saving cleaned data to a new CSV file
df.to_csv('data/cleaned_county_health_rankings.csv', index=False)

# %%
# Checking for missing values
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100
missing_df = pd.DataFrame({'Missing Values': missing_values, 
                           'Percentage (%)': missing_percentage})
missing_df = missing_df[missing_df['Missing Values'] > 0].sort_values('Percentage (%)', ascending=False)

print("Missing Values Analysis:")
display(missing_df)
# Out:
# Missing Values Analysis:
#              Missing Values  Percentage (%)
# denominator          115380       39.283112
# ci_upper             113904       38.780582
# ci_lower             113904       38.780582
# numerator             89285       30.398619
# raw_value             13430        4.572475
# year_start               10        0.003405
# year_end                 10        0.003405

# %%
df[df['year_start'].isna()][['county_name', 'state_name', 'measure_name', 'year_start', 'year_end']]
# Out:
#           county_name state_name  measure_name  year_start  year_end
# 28500  Kalawao County         HI  Unemployment         NaN       NaN
# 28501  Kalawao County         HI  Unemployment         NaN       NaN
# 28502  Kalawao County         HI  Unemployment         NaN       NaN
# 28503  Kalawao County         HI  Unemployment         NaN       NaN
# 28504  Kalawao County         HI  Unemployment         NaN       NaN
# 28505  Kalawao County         HI  Unemployment         NaN       NaN
# 28506  Kalawao County         HI  Unemployment         NaN       NaN
# 28507  Kalawao County         HI  Unemployment         NaN       NaN
# 28508  Kalawao County         HI  Unemployment         NaN       NaN
# 28509  Kalawao County         HI  Unemployment         NaN       NaN

# %% [markdown]
# Kalawao is the second smallest county in the US by population (82 people) which explains data quality issues. Will drop since it is negligible.

# %%
df = df[df['year_start'].notna()]

# %%
# Checking for missing values
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100
missing_df = pd.DataFrame({'Missing Values': missing_values, 
                           'Percentage (%)': missing_percentage})
missing_df = missing_df[missing_df['Missing Values'] > 0].sort_values('Percentage (%)', ascending=False)

print("Missing Values Analysis:")
display(missing_df)
# Out:
# Missing Values Analysis:
#              Missing Values  Percentage (%)
# denominator          115370       39.281045
# ci_upper             113894       38.778498
# ci_lower             113894       38.778498
# numerator             89275       30.396249
# raw_value             13420        4.569226
